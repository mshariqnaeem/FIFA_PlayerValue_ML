# %%
# import libraries 
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
#read in the CSV as a dataframe 
df = pd.read_csv(Path('fifa_cleaned.csv'))
df.head()
# Out:
#        id          name                       full_name birth_date  age  \
# 0  158023      L. Messi  Lionel Andrés Messi Cuccittini   24/06/87   31
# 1  190460    C. Eriksen    Christian  Dannemann Eriksen   14/02/92   27
# 2  195864      P. Pogba                      Paul Pogba   15/03/93   25
# 3  198219    L. Insigne                 Lorenzo Insigne   04/06/91   27
# 4  201024  K. Koulibaly               Kalidou Koulibaly   20/06/91   27
#
#    height_cm  weight_kgs  positions nationality  overall_rating  ...   LWB  \
# 0     170.18        72.1   CF,RW,ST   Argentina              94  ...  64+2
# 1     154.94        76.2  CAM,RM,CM     Denmark              88  ...  71+3
# 2     190.50        83.9     CM,CAM      France              88  ...  76+3
# 3     162.56        59.0      LW,ST       Italy              88  ...  63+3
# 4     187.96        88.9         CB     Senegal              88  ...  73+3
#
#     LDM   CDM   RDM   RWB    LB   LCB    CB   RCB    RB
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# name             0
# full_name        0
# birth_date       0
# age              0
#               ...
# LB            2065
# LCB           2065
# CB            2065
# RCB           2065
# RB            2065
# Length: 92, dtype: int64

# %%
df.size
# Out:
# 1651768

# %%
df = df.dropna()
df
# Out:
#            id               name                            full_name  \
# 0      158023           L. Messi       Lionel Andrés Messi Cuccittini
# 1      190460         C. Eriksen         Christian  Dannemann Eriksen
# 2      195864           P. Pogba                           Paul Pogba
# 3      198219         L. Insigne                      Lorenzo Insigne
# 5      203376        V. van Dijk                      Virgil van Dijk
# ...       ...                ...                                  ...
# 17938  176580          L. Suárez             Luis Alberto Suárez Díaz
# 17940  183277          E. Hazard                          Eden Hazard
# 17941  192985       K. De Bruyne                      Kevin De Bruyne
# 17943  190871          Neymar Jr        Neymar da Silva Santos Junior
# 17944   20801  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
#
#       birth_date  age  height_cm  weight_kgs  positions  nationality  \
# ...

# %%
df.size
# Out:
# 14352

# %%
df['value_euro'] = df['value_euro'].fillna(0) 
df['value_euro']=df['value_euro'].astype(int)
df.dtypes
# Out:
# C:\Users\RyanC\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\RyanC\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# id             int64
# name          object
# full_name     object
# birth_date    object
# age            int64
#                ...
# LB            object
# LCB           object
# ...

# %%
newdf=df.select_dtypes(include=["int64"])
newdf
# Out:
#            id  age  overall_rating  potential  international_reputation(1-5)  \
# 0      158023   31              94         94                              5
# 1      190460   27              88         89                              3
# 2      195864   25              88         91                              4
# 3      198219   27              88         88                              3
# 5      203376   27              88         90                              3
# ...       ...  ...             ...        ...                            ...
# 17938  176580   32              91         91                              5
# 17940  183277   28              91         91                              4
# 17941  192985   27              91         92                              4
# 17943  190871   27              92         92                              5
# 17944   20801   34              94         94                              5
#
# ...

# %%
ppp_df =pd.DataFrame(data = x_pca, columns=["PC 1", "PC 2", "PC 3"], index = index_values)
ppp_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1036/260953670.py in <module>
# ----> 1 ppp_df =pd.DataFrame(data = x_pca, columns=["PC 1", "PC 2", "PC 3"], index = index_values)
#       2 ppp_df.head()
#
# NameError: name 'pd' is not defined

# %%
newdf.columns
# Out:
# Index(['id', 'age', 'overall_rating', 'potential',
#        'international_reputation(1-5)', 'weak_foot(1-5)', 'skill_moves(1-5)',
#        'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys',
#        'dribbling', 'curve', 'freekick_accuracy', 'long_passing',
#        'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions',
#        'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots',
#        'aggression', 'interceptions', 'positioning', 'vision', 'penalties',
#        'composure', 'marking', 'standing_tackle', 'sliding_tackle',
#        'GK_diving', 'GK_handling', 'GK_kicking', 'GK_positioning',
#        'GK_reflexes'],
#       dtype='object')

# %%
newer_df = newdf.drop(['international_reputation(1-5)', 'weak_foot(1-5)', 'skill_moves(1-5)'], axis='columns')
newer_df
# Out:
#            id  age  overall_rating  potential  crossing  finishing  \
# 0      158023   31              94         94        86         95
# 1      190460   27              88         89        88         81
# 2      195864   25              88         91        80         75
# 3      198219   27              88         88        86         77
# 5      203376   27              88         90        53         52
# ...       ...  ...             ...        ...       ...        ...
# 17938  176580   32              91         91        77         92
# 17940  183277   28              91         91        81         84
# 17941  192985   27              91         92        93         82
# 17943  190871   27              92         92        83         87
# 17944   20801   34              94         94        84         94
#
#        heading_accuracy  short_passing  volleys  dribbling  ...  penalties  \
# 0                    70             92       86         97  ...         75
# ...
