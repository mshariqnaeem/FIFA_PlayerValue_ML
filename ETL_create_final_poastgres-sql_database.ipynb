# %%
# !pip install config
# Out:
# ...
#   Using cached config-0.5.1-py2.py3-none-any.whl (20 kB)
# ...

# %%
#import dependencies
from config import db_password
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from config import db_password
import psycopg2

# %%
#read in the CSV as a dataframe 
df = pd.read_csv("../Resource/fifa_cleaned.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2784/2773997734.py in <module>
#       1 #read in the CSV as a dataframe
# ----> 2 df = pd.read_csv('fifa_cleaned.csv')
#       3 df.head()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
# !pip install config

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17954 entries, 0 to 17953
# Data columns (total 77 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     17954 non-null  int64
#  1   Id                             17954 non-null  int64
#  2   Name                           17954 non-null  object
#  3   Age                            17954 non-null  int64
#  4   Height_Cm                      17954 non-null  float64
#  5   Weight_Kgs                     17954 non-null  float64
#  6   Positions                      17954 non-null  object
#  7   Nationality                    17954 non-null  object
#  8   Overall_Rating                 17954 non-null  int64
#  9   Potential                      17954 non-null  int64
#  10  Value_Euro                     17699 non-null  float64
#  11  International_Reputation(1-5)  17954 non-null  int64
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0             Id           Age     Height_Cm    Weight_Kgs  \
# count  17954.000000   17954.000000  17954.000000  17954.000000  17954.000000
# mean    8976.500000  215411.087780     25.565445    174.946921     75.301047
# std     5183.017702   29758.387106      4.705708     14.029449      7.083684
# min        0.000000      16.000000     17.000000    152.400000     49.900000
# 25%     4488.250000  201117.250000     22.000000    154.940000     69.900000
# 50%     8976.500000  222919.000000     25.000000    175.260000     74.800000
# 75%    13464.750000  237613.500000     29.000000    185.420000     79.800000
# max    17953.000000  247607.000000     46.000000    205.740000    110.200000
#
#        Overall_Rating     Potential    Value_Euro  \
# count    17954.000000  17954.000000  1.769900e+04
# mean        66.240169     71.430935  2.479280e+06
# std          6.963730      6.131339  5.687014e+06
# min         47.000000     48.000000  1.000000e+04
# ...

# %% [markdown]
# # Data Processing

# %%
# Display data types for each colums
df.dtypes
# Out:
# Unnamed: 0             int64
# Id                     int64
# Name                  object
# Age                    int64
# Height_Cm            float64
#                       ...
# Lcb                   object
# Cb                    object
# Rcb                   object
# Rb                    object
# Original_Position     object
# Length: 77, dtype: object

# %%
# itemise all colums within Dataframe
df.columns
# Out:
# Index(['Unnamed: 0', 'Id', 'Name', 'Age', 'Height_Cm', 'Weight_Kgs',
#        'Positions', 'Nationality', 'Overall_Rating', 'Potential', 'Value_Euro',
#        'International_Reputation(1-5)', 'Skill_Moves(1-5)', 'Work_Rate',
#        'Club_Team', 'National_Team', 'Crossing', 'Finishing',
#        'Heading_Accuracy', 'Short_Passing', 'Volleys', 'Dribbling', 'Curve',
#        'Freekick_Accuracy', 'Long_Passing', 'Ball_Control', 'Acceleration',
#        'Sprint_Speed', 'Agility', 'Reactions', 'Balance', 'Shot_Power',
#        'Jumping', 'Stamina', 'Strength', 'Long_Shots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'Standing_Tackle', 'Sliding_Tackle', 'Gk_Diving',
#        'Gk_Handling', 'Gk_Kicking', 'Gk_Positioning', 'Gk_Reflexes', 'Ls',
#        'St', 'Rs', 'Lw', 'Lf', 'Cf', 'Rf', 'Rw', 'Lam', 'Cam', 'Ram', 'Lm',
#        'Lcm', 'Cm', 'Rcm', 'Rm', 'Lwb', 'Ldm', 'Cdm', 'Rdm', 'Rwb', 'Lb',
# ...

# %%
df.nunique()
# Out:
# Unnamed: 0           17954
# Id                   17954
# Name                 16995
# Age                     29
# Height_Cm               20
#                      ...
# Lcb                    109
# Cb                     109
# Rcb                    109
# Rb                      97
# Original_Position      890
# Length: 77, dtype: int64

# %%
df['Positions'].value_counts()
# Out:
# MF    7178
# DF    6107
# FW    2604
# GK    2065
# Name: Positions, dtype: int64

# %%
df[df.Positions == 'GK']
# Out:
#        Unnamed: 0      Id           Name  Age  Height_Cm  Weight_Kgs  \
# 8               8  167495       M. Neuer   32     193.04        92.1
# 11             11  192119    T. Courtois   26     198.12        96.2
# 12             12  192448  M. ter Stegen   26     187.96        84.8
# 27             27  193041       K. Navas   32     185.42        79.8
# 32             32  206585           Kepa   24     185.42        84.8
# ...           ...     ...            ...  ...        ...         ...
# 17921       17921  162835  S. Handanovič   34     193.04        92.1
# 17923       17923  167948      H. Lloris   32     187.96        82.1
# 17936       17936  200389       J. Oblak   26     187.96        87.1
# 17942       17942  193080         De Gea   28     193.04        76.2
# 17951       17951  235155     J. Bekkema   22     185.42        89.8
#
#       Positions  Nationality  Overall_Rating  Potential  ...  Ldm  Cdm  Rdm  \
# ...

# %%
df['Club_Team'].value_counts()
# Out:
# FC Barcelona           33
# AS Monaco              33
# Cardiff City           33
# Valencia CF            33
# Arsenal                33
#                        ..
# Greece                  2
# Sweden                  2
# Italy                   1
# Republic of Ireland     1
# Poland                  1
# Name: Club_Team, Length: 687, dtype: int64

# %%
df.drop(['Ls','St','Rs','Lw','Lf','Cf','Rf','Rw','Lam','Cam','Ram','Lm','Lcm','Cm','Rcm','Rm','Lwb','Ldm','Cdm','Rdm','Rwb','Lb','Lcb','Cb','Rcb','Rb','National_Team','Club_Team','Name','Nationality','Work_Rate','Original_Position'], axis=1, inplace=True)
df.head()
# Out:
#    Unnamed: 0      Id  Age  Height_Cm  Weight_Kgs Positions  Overall_Rating  \
# 0           0  158023   31     170.18        72.1        FW              94
# 1           1  190460   27     154.94        76.2        MF              88
# 2           2  195864   25     190.50        83.9        MF              88
# 3           3  198219   27     162.56        59.0        MF              88
# 4           4  201024   27     187.96        88.9        DF              88
#
#    Potential   Value_Euro  International_Reputation(1-5)  ...  Penalties  \
# 0         94  110500000.0                              5  ...         75
# 1         89   69500000.0                              3  ...         67
# 2         91   73000000.0                              4  ...         82
# 3         88   62000000.0                              3  ...         61
# 4         91   60000000.0                              3  ...         33
#
#    Composure  Marking  Standing_Tackle  Sliding_Tackle  Gk_Diving  \
# ...

# %%
df.drop(['Positions'], axis=1, inplace=True)

# %%
df.to_csv('revised_fifa_data.csv')
