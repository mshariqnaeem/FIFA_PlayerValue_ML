# %%
# import libraries 
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
#read in the CSV as a dataframe 
df = pd.read_csv(Path('C:/Users/Sydney Kieswetter/Class/Capstone_Group12/Resources/Modified_fifa_data.csv'))
df.head()
# Out:
#    Unnamed: 0      Id          Name  Age  Height_Cm  Weight_Kgs Positions  \
# 0           0  158023      L. Messi   31     170.18        72.1        FW
# 1           1  190460    C. Eriksen   27     154.94        76.2        MF
# 2           2  195864      P. Pogba   25     190.50        83.9        MF
# 3           3  198219    L. Insigne   27     162.56        59.0        MF
# 4           4  201024  K. Koulibaly   27     187.96        88.9        DF
#
#   Nationality  Overall_Rating  Potential  ...   Ldm   Cdm   Rdm   Rwb    Lb  \
# 0   Argentina              94         94  ...  61+2  61+2  61+2  64+2  59+2
# 1     Denmark              88         89  ...  71+3  71+3  71+3  71+3  66+3
# 2      France              88         91  ...  77+3  77+3  77+3  76+3  74+3
# 3       Italy              88         88  ...  58+3  58+3  58+3  63+3  58+3
# 4     Senegal              88         91  ...  77+3  77+3  77+3  73+3  76+3
#
#     Lcb    Cb   Rcb    Rb  Original_Position
# 0  48+2  48+2  48+2  59+2           CF,RW,ST
# 1  57+3  57+3  57+3  66+3          CAM,RM,CM
# 2  72+3  72+3  72+3  74+3             CM,CAM
# 3  44+3  44+3  44+3  58+3              LW,ST
# 4  85+3  85+3  85+3  76+3                 CB
#
# [5 rows x 77 columns]

# %%
df.drop("Unnamed: 0",axis=1, inplace=True)
df.head()
# Out:
#        Id          Name  Age  Height_Cm  Weight_Kgs Positions Nationality  \
# 0  158023      L. Messi   31     170.18        72.1        FW   Argentina
# 1  190460    C. Eriksen   27     154.94        76.2        MF     Denmark
# 2  195864      P. Pogba   25     190.50        83.9        MF      France
# 3  198219    L. Insigne   27     162.56        59.0        MF       Italy
# 4  201024  K. Koulibaly   27     187.96        88.9        DF     Senegal
#
#    Overall_Rating  Potential   Value_Euro  ...   Ldm   Cdm   Rdm   Rwb    Lb  \
# 0              94         94  110500000.0  ...  61+2  61+2  61+2  64+2  59+2
# 1              88         89   69500000.0  ...  71+3  71+3  71+3  71+3  66+3
# 2              88         91   73000000.0  ...  77+3  77+3  77+3  76+3  74+3
# 3              88         88   62000000.0  ...  58+3  58+3  58+3  63+3  58+3
# 4              88         91   60000000.0  ...  77+3  77+3  77+3  73+3  76+3
#
#     Lcb    Cb   Rcb    Rb  Original_Position
# 0  48+2  48+2  48+2  59+2           CF,RW,ST
# 1  57+3  57+3  57+3  66+3          CAM,RM,CM
# 2  72+3  72+3  72+3  74+3             CM,CAM
# 3  44+3  44+3  44+3  58+3              LW,ST
# 4  85+3  85+3  85+3  76+3                 CB
#
# [5 rows x 76 columns]

# %%
df.shape
# Out:
# (17954, 76)

# %%
# Create tables 
dfdemo=df.filter(["Age","Height_Cm","Weight_Kgs","Value_Euro"],axis=1)
dfdemo.head()
# Out:
#    Age  Height_Cm  Weight_Kgs   Value_Euro
# 0   31     170.18        72.1  110500000.0
# 1   27     154.94        76.2   69500000.0
# 2   25     190.50        83.9   73000000.0
# 3   27     162.56        59.0   62000000.0
# 4   27     187.96        88.9   60000000.0

# %%
dfskills=df.filter(["Crossing","Finishing","Heading_Accuracy","Short_Passing","Volleys","Dribbling","Curve","Freekick_Accuracy","Long_Passing","Ball_Control","Acceleration","Sprint_Speed","Agility","Reactions","Balance","Shot_Power","Jumping","Stamina","Strength","Long_Shots","Aggression","Interceptions","Positioning","Vision","Penalties","Composure","Marking","Standing_Tackle","Sliding_Tackle","Value_Euro"],axis=1)
dfskills.head()
# Out:
#    Crossing  Finishing  Heading_Accuracy  Short_Passing  Volleys  Dribbling  \
# 0        86         95                70             92       86         97
# 1        88         81                52             91       80         84
# 2        80         75                75             86       85         87
# 3        86         77                56             85       74         90
# 4        30         22                83             68       14         69
#
#    Curve  Freekick_Accuracy  Long_Passing  Ball_Control  ...  Aggression  \
# 0     93                 94            89            96  ...          48
# 1     86                 87            89            91  ...          46
# 2     85                 82            90            90  ...          78
# 3     87                 77            78            93  ...          34
# 4     28                 28            60            63  ...          87
#
#    Interceptions  Positioning  Vision  Penalties  Composure  Marking  \
# 0             22           94      94         75         96       33
# 1             56           84      91         67         88       59
# 2             64           82      88         82         87       63
# 3             26           83      87         61         83       51
# 4             88           24      49         33         80       91
#
#    Standing_Tackle  Sliding_Tackle   Value_Euro
# 0               28              26  110500000.0
# 1               57              22   69500000.0
# 2               67              67   73000000.0
# 3               24              22   62000000.0
# 4               88              87   60000000.0
#
# [5 rows x 30 columns]

# %%
dfDF=df[df.Positions=="DF"]
dfDF.head()
# Out:
#         Id          Name  Age  Height_Cm  Weight_Kgs Positions  Nationality  \
# 4   201024  K. Koulibaly   27     187.96        88.9        DF      Senegal
# 5   203376   V. van Dijk   27     193.04        92.1        DF  Netherlands
# 6   231747     K. Mbappé   20     152.40        73.0        DF       France
# 14  209331      M. Salah   26     175.26        71.2        DF        Egypt
# 16  232363   M. Škriniar   24     187.96        79.8        DF     Slovakia
#
#     Overall_Rating  Potential  Value_Euro  ...   Ldm   Cdm   Rdm   Rwb    Lb  \
# 4               88         91  60000000.0  ...  77+3  77+3  77+3  73+3  76+3
# 5               88         90  59500000.0  ...  82+3  82+3  82+3  78+3  80+3
# 6               88         95  81000000.0  ...  62+3  62+3  62+3  66+3  62+3
# 14              89         90  78500000.0  ...  66+3  66+3  66+3  70+3  66+3
# 16              86         93  53500000.0  ...  79+2  79+2  79+2  74+2  77+2
#
#      Lcb    Cb   Rcb    Rb  Original_Position
# 4   85+3  85+3  85+3  76+3                 CB
# 5   86+3  86+3  86+3  80+3                 CB
# 6   54+3  54+3  54+3  62+3           RW,ST,RM
# 14  57+3  57+3  57+3  66+3              RW,ST
# 16  84+2  84+2  84+2  77+2                 CB
#
# [5 rows x 76 columns]

# %%
dfFW=df[df.Positions=="FW"]
dfFW.head()
# Out:
#         Id          Name  Age  Height_Cm  Weight_Kgs Positions Nationality  \
# 0   158023      L. Messi   31     170.18        72.1        FW   Argentina
# 7   153079     S. Agüero   30     172.72        69.9        FW   Argentina
# 9   179813     E. Cavani   32     185.42        77.1        FW     Uruguay
# 13  194765  A. Griezmann   27     175.26        73.0        FW      France
# 18  167664    G. Higuaín   31     185.42        88.9        FW   Argentina
#
#     Overall_Rating  Potential   Value_Euro  ...   Ldm   Cdm   Rdm   Rwb    Lb  \
# 0               94         94  110500000.0  ...  61+2  61+2  61+2  64+2  59+2
# 7               89         89   64500000.0  ...  56+3  56+3  56+3  58+3  53+3
# 9               89         89   60000000.0  ...  65+3  65+3  65+3  67+3  65+3
# 13              89         90   78000000.0  ...  70+3  70+3  70+3  72+3  70+3
# 18              87         87   48500000.0  ...  53+3  53+3  53+3  55+3  51+3
#
#      Lcb    Cb   Rcb    Rb  Original_Position
# 0   48+2  48+2  48+2  59+2           CF,RW,ST
# 7   47+3  47+3  47+3  53+3                 ST
# 9   63+3  63+3  63+3  65+3                 ST
# 13  65+3  65+3  65+3  70+3              CF,ST
# 18  48+3  48+3  48+3  51+3                 ST
#
# [5 rows x 76 columns]

# %%
dfGK=df[df.Positions=="GK"]
dfGK.head()
# Out:
#         Id           Name  Age  Height_Cm  Weight_Kgs Positions Nationality  \
# 8   167495       M. Neuer   32     193.04        92.1        GK     Germany
# 11  192119    T. Courtois   26     198.12        96.2        GK     Belgium
# 12  192448  M. ter Stegen   26     187.96        84.8        GK     Germany
# 27  193041       K. Navas   32     185.42        79.8        GK  Costa Rica
# 32  206585           Kepa   24     185.42        84.8        GK       Spain
#
#     Overall_Rating  Potential  Value_Euro  ...  Ldm  Cdm  Rdm  Rwb   Lb  Lcb  \
# 8               89         89  38000000.0  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 11              89         90  53500000.0  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 12              89         92  58000000.0  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 27              87         87  30500000.0  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 32              84         90  31000000.0  ...  NaN  NaN  NaN  NaN  NaN  NaN
#
#      Cb  Rcb   Rb  Original_Position
# 8   NaN  NaN  NaN                 GK
# 11  NaN  NaN  NaN                 GK
# 12  NaN  NaN  NaN                 GK
# 27  NaN  NaN  NaN                 GK
# 32  NaN  NaN  NaN                 GK
#
# [5 rows x 76 columns]

# %%
dfMF=df[df.Positions=="MF"]
dfMF.head()
# Out:
#         Id             Name  Age  Height_Cm  Weight_Kgs Positions Nationality  \
# 1   190460       C. Eriksen   27     154.94        76.2        MF     Denmark
# 2   195864         P. Pogba   25     190.50        83.9        MF      France
# 3   198219       L. Insigne   27     162.56        59.0        MF       Italy
# 10  189511  Sergio Busquets   30     187.96        76.2        MF       Spain
# 15  211110        P. Dybala   25     152.40        74.8        MF   Argentina
#
#     Overall_Rating  Potential  Value_Euro  ...   Ldm   Cdm   Rdm   Rwb    Lb  \
# 1               88         89  69500000.0  ...  71+3  71+3  71+3  71+3  66+3
# 2               88         91  73000000.0  ...  77+3  77+3  77+3  76+3  74+3
# 3               88         88  62000000.0  ...  58+3  58+3  58+3  63+3  58+3
# 10              89         89  51500000.0  ...  86+3  86+3  86+3  79+3  78+3
# 15              89         94  89000000.0  ...  58+3  58+3  58+3  62+3  56+3
#
#      Lcb    Cb   Rcb    Rb  Original_Position
# 1   57+3  57+3  57+3  66+3          CAM,RM,CM
# 2   72+3  72+3  72+3  74+3             CM,CAM
# 3   44+3  44+3  44+3  58+3              LW,ST
# 10  82+3  82+3  82+3  78+3             CDM,CM
# 15  45+3  45+3  45+3  56+3             CAM,RW
#
# [5 rows x 76 columns]

# %%
dfrating=df.filter(["Overall_Rating","International_Reputation_1_5","Skill_Moves_1_5","Value_Euro"],axis=1)
dfrating.head()
# Out:
#    Overall_Rating  International_Reputation_1_5  Skill_Moves_1_5   Value_Euro
# 0              94                             5                4  110500000.0
# 1              88                             3                4   69500000.0
# 2              88                             4                5   73000000.0
# 3              88                             3                4   62000000.0
# 4              88                             3                2   60000000.0

# %%
print(dfdemo.shape)
print(dfskills.shape)
print(dfDF.shape)
print(dfFW.shape)
print(dfMF.shape)
print(dfGK.shape)
print(dfrating.shape)
# Out:
# (17954, 4)
# (17954, 30)
# (6107, 76)
# (2604, 76)
# (7178, 76)
# (2065, 76)
# (17954, 4)

# %% [markdown]
# # Skills Model

# %%
dfskills.isnull().sum()
# Out:
# Crossing               0
# Finishing              0
# Heading_Accuracy       0
# Short_Passing          0
# Volleys                0
# Dribbling              0
# Curve                  0
# Freekick_Accuracy      0
# Long_Passing           0
# Ball_Control           0
# Acceleration           0
# Sprint_Speed           0
# Agility                0
# Reactions              0
# Balance                0
# Shot_Power             0
# Jumping                0
# Stamina                0
# Strength               0
# Long_Shots             0
# Aggression             0
# Interceptions          0
# Positioning            0
# Vision                 0
# Penalties              0
# Composure              0
# Marking                0
# Standing_Tackle        0
# Sliding_Tackle         0
# Value_Euro           255
# dtype: int64

# %%
NoNull=dfskills.dropna()

# %%
# y variable/ target variable 
y= NoNull.Value_Euro

# %%
x=NoNull.drop(columns="Value_Euro").values

# %%
x.shape
# Out:
# (17699, 29)

# %%
y.shape
# Out:
# (17699,)

# %%
#y = y.values.reshape(-1,1)

# %%
# split into training and testing sets 
from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1/3, random_state=0)

x_train.shape
# remember had to remove stratisfy because of small data size
# Out:
# (11799, 29)

# %%
model =LinearRegression()

# %%
#fit the model- this needed to be a variable 
c = model.fit(x_train, y_train)

# %%
# Use model to predict on Test Data 
y_pred=c.predict(x_test)
print(y_pred)
# Out:
# [ 3042921.55051463  6838244.83261156 -3522085.08513407 ...
#   3328969.51219276 -4149888.68121517  6304268.39812916]

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test, y_pred))
# Out:
# 0.3396281113676335

# %%
y_pred_train=

# %%
print(r2_score(y_train, y_pred_train))

# %%
# plot the results- actual vs predicted 
plt.scatter(y_test, y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %% [markdown]
# # Demographic Model

# %%
dfdemo.isnull().sum()
# Out:
# Age             0
# Height_Cm       0
# Weight_Kgs      0
# Value_Euro    255
# dtype: int64

# %%
NoNullDemo=dfdemo.dropna()

# %%
# y variable/ target variable 
y= NoNullDemo.Value_Euro

# %%
x=NoNullDemo.drop(columns="Value_Euro").values

# %%
x.shape
# Out:
# (17699, 3)

# %%
y.shape
# Out:
# (17699,)

# %%
# split into training and testing sets 
from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1/3, random_state=0)

x_train.shape
# remember had to remove stratisfy because of small data size
# Out:
# (11799, 3)

# %%
model =LinearRegression()

# %%
#fit the model- this needed to be a variable 
c = model.fit(x_train, y_train)

# %%
# Use model to predict on Test Data 
y_pred=c.predict(x_test)
print(y_pred)
# Out:
# [2757267.77082137 2939279.8571874  2136295.48762012 ... 2924793.42971693
#  1496243.9730964  2522233.01556036]

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test, y_pred))
# Out:
# 0.008043789614715857

# %%
# plot the results- actual vs predicted 
plt.scatter(y_test, y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %% [markdown]
# # Ratings Model

# %%
dfrating.isnull().sum()
# Out:
# Overall_Rating                    0
# International_Reputation_1_5      0
# Skill_Moves_1_5                   0
# Value_Euro                      255
# dtype: int64

# %%
NoNullRating=dfrating.dropna()

# %%
# y variable/ target variable 
y= NoNullRating.Value_Euro

# %%
x=NoNullRating.drop(columns="Value_Euro").values

# %%
x.shape
# Out:
# (17699, 3)

# %%
y.shape
# Out:
# (17699,)

# %%
# split into training and testing sets 
from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1/3, random_state=0)

x_train.shape
# remember had to remove stratisfy because of small data size
# Out:
# (11799, 3)

# %%
model =LinearRegression()

# %%
#fit the model- this needed to be a variable 
c = model.fit(x_train, y_train)

# %%
# Use model to predict on Test Data 
y_pred=c.predict(x_test)
print(y_pred)
# Out:
# [ 1823787.05814547  4389810.1411395   -666514.09030671 ...
#   1823787.05814547 -2727744.74069503  5130168.28275989]

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test, y_pred))
# Out:
# 0.5515632793602109

# %%
# plot the results- actual vs predicted 
plt.scatter(y_test, y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %% [markdown]
# # Goal Keeping Model

# %%
# drop addition columns and strings (names, club and national teams, nationality, work rate)
dfGK.drop(['Ls','St','Rs','Lw','Lf','Cf','Rf','Rw','Lam','Cam','Ram','Lm','Lcm','Cm','Rcm','Rm','Lwb','Ldm','Cdm','Rdm','Rwb','Lb','Lcb','Cb','Rcb','Rb','National_Team','Club_Team','Name','Nationality','Work_Rate','Original_Position','Positions'], axis=1, inplace=True)
dfGK.head()
# Out:
# C:\Users\Sydney Kieswetter\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#         Id  Age  Height_Cm  Weight_Kgs  Overall_Rating  Potential  Value_Euro  \
# 8   167495   32     193.04        92.1              89         89  38000000.0
# 11  192119   26     198.12        96.2              89         90  53500000.0
# 12  192448   26     187.96        84.8              89         92  58000000.0
# 27  193041   32     185.42        79.8              87         87  30500000.0
# 32  206585   24     185.42        84.8              84         90  31000000.0
#
#     International_Reputation_1_5  Skill_Moves_1_5  Crossing  ...  Penalties  \
# 8                              5                1        15  ...         47
# 11                             4                1        14  ...         27
# 12                             3                1        18  ...         25
# 27                             3                1        11  ...         25
# 32                             1                1        25  ...         24
#
#     Composure  Marking  Standing_Tackle  Sliding_Tackle  Gk_Diving  \
# 8          70       17               10              11         90
# 11         66       20               18              16         85
# 12         70       25               13              10         87
# 27         67       28               14              14         90
# 32         63       19               18              16         84
#
#     Gk_Handling  Gk_Kicking  Gk_Positioning  Gk_Reflexes
# 8            86          91              87           87
# 11           91          72              86           88
# 12           85          88              86           90
# 27           81          75              82           90
# 32           82          79              80           85
#
# [5 rows x 43 columns]

# %%
dfGK.isnull().sum()
# Out:
# Id                               0
# Age                              0
# Height_Cm                        0
# Weight_Kgs                       0
# Overall_Rating                   0
# Potential                        0
# Value_Euro                      41
# International_Reputation_1_5     0
# Skill_Moves_1_5                  0
# Crossing                         0
# Finishing                        0
# Heading_Accuracy                 0
# Short_Passing                    0
# Volleys                          0
# Dribbling                        0
# Curve                            0
# Freekick_Accuracy                0
# Long_Passing                     0
# Ball_Control                     0
# Acceleration                     0
# Sprint_Speed                     0
# Agility                          0
# Reactions                        0
# Balance                          0
# Shot_Power                       0
# Jumping                          0
# Stamina                          0
# Strength                         0
# Long_Shots                       0
# Aggression                       0
# Interceptions                    0
# Positioning                      0
# Vision                           0
# Penalties                        0
# Composure                        0
# Marking                          0
# Standing_Tackle                  0
# Sliding_Tackle                   0
# Gk_Diving                        0
# Gk_Handling                      0
# Gk_Kicking                       0
# Gk_Positioning                   0
# Gk_Reflexes                      0
# dtype: int64

# %%
NoNullgoal=dfGK.dropna()

# %%
x=NoNullgoal.drop(columns="Value_Euro").values

# %%
# y variable/ target variable 
y= NoNullgoal.Value_Euro

# %%
x.shape
# Out:
# (2024, 42)

# %%
y.shape
# Out:
# (2024,)

# %%
y = y.values.reshape(-1,1)

# %%
# split into training and testing sets 
from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1/3, random_state=0)

x_train.shape
# remember had to remove stratisfy because of small data size
# Out:
#
#  [-1.04684186e+06]
#  [ 3.24998232e+06]
#  [ 9.65304499e+05]
#  [ 5.81210194e+05]
#  [-1.42004878e+06]
#  [ 1.92534596e+06]
#  [ 1.98394742e+05]
#  [-2.10241538e+06]
#  [ 2.15072732e+06]
#  [-1.95136320e+06]
#  [ 3.81400131e+06]
#  [-9.06697195e+04]
#  [-1.73398453e+06]
#  [-1.77215280e+06]
#  [ 4.63490512e+05]
#  [-1.88909781e+06]
#  [-4.12170161e+05]
#  [ 3.81330098e+05]
#  [ 3.49921556e+06]
#  [ 2.83292669e+06]
#  [-2.90159951e+05]
#  [ 2.20920901e+05]
#  [ 1.03167390e+06]
#  [ 1.29468959e+06]
#  [ 5.13209980e+05]
#  [ 4.09886040e+06]
#  [ 5.91899923e+05]
#  [ 3.18648003e+06]
#  [-1.37042598e+06]
#  [ 3.41853879e+06]
#  [ 7.31110439e+06]
#  [-1.33873641e+06]
#  [ 8.04548222e+06]
#  [ 1.22956062e+06]
#  [-5.24061508e+05]
#  [ 3.07470648e+05]
#  [ 1.38139481e+06]
#  [ 2.28591503e+05]
#  [ 1.31366159e+05]
#  [ 3.28082256e+06]
#  [ 3.14033926e+06]
#  [-9.76652801e+05]
#  [ 1.11484103e+06]
#  [-3.14544728e+05]
#  [ 2.60656719e+06]
#  [ 1.64611077e+06]
#  [ 8.66230451e+04]
#  [-2.98505699e+06]
#  [ 1.98391155e+06]
#  [ 3.03450971e+06]
#  [ 3.70166077e+06]
#  [-1.59178864e+06]
#  [ 2.97596506e+06]
#  [-2.54072972e+06]
#  [ 8.50371506e+05]
#  [ 2.69293998e+06]
#  [ 4.84121067e+06]
#  [ 1.15235426e+06]
#  [ 8.88349124e+06]
#  [ 1.56603221e+06]
#  [-1.15750592e+06]
#  [ 4.21897998e+06]
#  [ 1.79637978e+06]
#  [ 2.50905396e+06]
#  [-1.36699077e+05]
#  [-9.51079422e+05]
#  [ 1.68658994e+07]
#  [-2.34969423e+06]
#  [-1.29536412e+06]
#  [ 2.34284937e+07]
#  [ 2.27593894e+06]
#  [ 3.67199898e+06]
#  [ 2.41164122e+06]
#  [-1.91135355e+06]
#  [-1.76263814e+06]
#  [-4.53026861e+05]
#  [-3.05144439e+05]
#  [ 3.76296681e+06]
#  [-4.22473249e+05]
#  [ 4.45418509e+05]
#  [ 1.77418475e+06]
#  [ 8.30344929e+05]
#  [ 5.41770975e+05]
#  [ 1.61982946e+06]
#  [-1.45510809e+06]
#  [ 5.51255134e+05]
#  [ 1.06819201e+06]
#  [ 2.98478961e+06]
#  [ 4.80283259e+06]
#  [-1.69145181e+06]
#  [ 2.52791382e+06]
#  [-8.95302238e+05]
#  [ 1.17417873e+06]
#  [ 3.63583507e+06]
#  [-1.59348347e+06]
#  [ 7.69201161e+05]
#  [ 2.42007630e+06]
#  [ 2.88094075e+06]
#  [ 1.19144506e+06]
#  [ 2.89589157e+05]
#  [ 1.60956380e+06]
#  [ 1.33674686e+06]
#  [ 5.62276481e+06]
#  [ 1.95582275e+07]
#  [ 2.11820347e+06]
#  [ 2.66736452e+06]
#  [ 1.00207918e+07]
#  [-1.35791865e+05]
#  [ 4.54548697e+06]
#  [ 3.56744230e+05]
#  [-1.88098831e+06]
#  [ 1.55620943e+05]
#  [-8.04412367e+05]
#  [ 1.45793967e+06]
#  [ 8.12062349e+05]
#  [ 4.09732749e+06]
#  [ 4.35349264e+06]
#  [-8.27816844e+05]
#  [ 6.92097379e+05]
#  [ 2.36883946e+06]
#  [ 7.57465274e+06]
#  [ 2.50483664e+06]
#  [ 1.54379198e+07]
#  [ 1.98764800e+06]
#  [-3.09742496e+06]
#  [-6.19172164e+05]
#  [ 8.27657153e+05]
#  [-1.16032864e+06]
#  [ 1.09791087e+05]
#  [-1.93498286e+06]
#  [ 3.29739852e+06]
#  [-2.48847730e+05]
#  [-2.30520216e+06]
#  [-3.31304440e+05]
#  [ 4.32251957e+05]
#  [ 6.71382919e+04]
#  [ 2.88174723e+06]
#  [ 5.54076305e+06]
#  [-2.30739361e+05]
#  [ 2.76789967e+06]
#  [ 1.86219192e+06]
#  [ 6.79261121e+05]
#  [ 1.09598398e+06]
#  [ 3.04366024e+06]
#  [ 8.07012017e+05]
#  [ 1.29810400e+06]
#  [ 5.04554469e+05]
#  [ 6.20821613e+04]
#  [-1.53289392e+06]
#  [ 5.37432071e+06]
#  [ 8.68221439e+06]
#  [ 1.49262023e+06]
#  [-2.14995290e+06]
#  [ 2.59475451e+06]
#  [ 1.32076870e+06]
#  [ 9.02562297e+05]
#  [-7.31895576e+05]
#  [ 1.45977944e+06]
#  [ 1.56763330e+06]
#  [ 9.15498377e+05]
#  [-1.86340220e+05]
#  [ 6.33232247e+06]
#  [ 1.52635478e+06]]

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test, y_pred))
# Out:
# 0.5349345379553678

# %%
# plot the results- actual vs predicted 
plt.scatter(y_test, y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %% [markdown]
# # Defence Model

# %%
# drop addition columns and strings (names, club and national teams, nationality, work rate)
dfDF.drop(['Ls','St','Rs','Lw','Lf','Cf','Rf','Rw','Lam','Cam','Ram','Lm','Lcm','Cm','Rcm','Rm','Lwb','Ldm','Cdm','Rdm','Rwb','Lb','Lcb','Cb','Rcb','Rb','National_Team','Club_Team','Name','Nationality','Work_Rate','Original_Position','Positions'], axis=1, inplace=True)
dfDF.head()
# Out:
# C:\Users\Sydney Kieswetter\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#         Id  Age  Height_Cm  Weight_Kgs  Overall_Rating  Potential  Value_Euro  \
# 4   201024   27     187.96        88.9              88         91  60000000.0
# 5   203376   27     193.04        92.1              88         90  59500000.0
# 6   231747   20     152.40        73.0              88         95  81000000.0
# 14  209331   26     175.26        71.2              89         90  78500000.0
# 16  232363   24     187.96        79.8              86         93  53500000.0
#
#     International_Reputation_1_5  Skill_Moves_1_5  Crossing  ...  Penalties  \
# 4                              3                2        30  ...         33
# 5                              3                2        53  ...         62
# 6                              3                5        77  ...         70
# 14                             3                4        78  ...         75
# 16                             1                2        40  ...         56
#
#     Composure  Marking  Standing_Tackle  Sliding_Tackle  Gk_Diving  \
# 4          80       91               88              87          7
# 5          87       90               89              84         13
# 6          86       34               34              32         13
# 14         91       38               43              41         14
# 16         81       92               89              84         10
#
#     Gk_Handling  Gk_Kicking  Gk_Positioning  Gk_Reflexes
# 4            11           7              13            5
# 5            10          13              11           11
# 6             5           7              11            6
# 14           14           9              11           14
# 16           13          12               8           12
#
# [5 rows x 43 columns]

# %%
dfDF.isnull().sum()
# Out:
# Id                               0
# Age                              0
# Height_Cm                        0
# Weight_Kgs                       0
# Overall_Rating                   0
# Potential                        0
# Value_Euro                      84
# International_Reputation_1_5     0
# Skill_Moves_1_5                  0
# Crossing                         0
# Finishing                        0
# Heading_Accuracy                 0
# Short_Passing                    0
# Volleys                          0
# Dribbling                        0
# Curve                            0
# Freekick_Accuracy                0
# Long_Passing                     0
# Ball_Control                     0
# Acceleration                     0
# Sprint_Speed                     0
# Agility                          0
# Reactions                        0
# Balance                          0
# Shot_Power                       0
# Jumping                          0
# Stamina                          0
# Strength                         0
# Long_Shots                       0
# Aggression                       0
# Interceptions                    0
# Positioning                      0
# Vision                           0
# Penalties                        0
# Composure                        0
# Marking                          0
# Standing_Tackle                  0
# Sliding_Tackle                   0
# Gk_Diving                        0
# Gk_Handling                      0
# Gk_Kicking                       0
# Gk_Positioning                   0
# Gk_Reflexes                      0
# dtype: int64

# %%
NoNulldef=dfDF.dropna()

# %%
x=NoNulldef.drop(columns="Value_Euro").values

# %%
# y variable/ target variable 
y= NoNulldef.Value_Euro

# %%
x.shape
# Out:
# (6023, 42)

# %%
y.shape
# Out:
# (6023,)

# %%
y = y.values.reshape(-1,1)

# %%
# split into training and testing sets 
from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1/3, random_state=0)

x_train.shape
# remember had to remove stratisfy because of small data size
# Out:
# (4015, 42)

# %%
model =LinearRegression()

# %%
#fit the model- this needed to be a variable 
c = model.fit(x_train, y_train)

# %%
# Use model to predict on Test Data 
y_pred=c.predict(x_test)
print(y_pred)
# Out:
# [[ -90931.42995537]
#  [2094134.4206221 ]
#  [1071121.25323606]
#  ...
#  [-997934.83895743]
#  [5233361.37224604]
#  [-148904.96631391]]

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test, y_pred))
# Out:
# 0.5937598010599527

# %%
# plot the results- actual vs predicted 
plt.scatter(y_test, y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %% [markdown]
# # Midfeild Model

# %%
# drop addition columns and strings (names, club and national teams, nationality, work rate)
dfMF.drop(['Ls','St','Rs','Lw','Lf','Cf','Rf','Rw','Lam','Cam','Ram','Lm','Lcm','Cm','Rcm','Rm','Lwb','Ldm','Cdm','Rdm','Rwb','Lb','Lcb','Cb','Rcb','Rb','National_Team','Club_Team','Name','Nationality','Work_Rate','Original_Position','Positions'], axis=1, inplace=True)
dfMF.head()
# Out:
# C:\Users\Sydney Kieswetter\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#         Id  Age  Height_Cm  Weight_Kgs  Overall_Rating  Potential  Value_Euro  \
# 1   190460   27     154.94        76.2              88         89  69500000.0
# 2   195864   25     190.50        83.9              88         91  73000000.0
# 3   198219   27     162.56        59.0              88         88  62000000.0
# 10  189511   30     187.96        76.2              89         89  51500000.0
# 15  211110   25     152.40        74.8              89         94  89000000.0
#
#     International_Reputation_1_5  Skill_Moves_1_5  Crossing  ...  Penalties  \
# 1                              3                4        88  ...         67
# 2                              4                5        80  ...         82
# 3                              3                4        86  ...         61
# 10                             4                3        62  ...         60
# 15                             3                4        82  ...         86
#
#     Composure  Marking  Standing_Tackle  Sliding_Tackle  Gk_Diving  \
# 1          88       59               57              22          9
# 2          87       63               67              67          5
# 3          83       51               24              22          8
# 10         93       90               86              80          5
# 15         84       23               20              20          5
#
#     Gk_Handling  Gk_Kicking  Gk_Positioning  Gk_Reflexes
# 1            14           7               7            6
# 2             6           2               4            3
# 3             4          14               9           10
# 10            8          13               9           13
# 15            4           4               5            8
#
# [5 rows x 43 columns]

# %%
dfMF.isnull().sum()
# Out:
# Id                               0
# Age                              0
# Height_Cm                        0
# Weight_Kgs                       0
# Overall_Rating                   0
# Potential                        0
# Value_Euro                      96
# International_Reputation_1_5     0
# Skill_Moves_1_5                  0
# Crossing                         0
# Finishing                        0
# Heading_Accuracy                 0
# Short_Passing                    0
# Volleys                          0
# Dribbling                        0
# Curve                            0
# Freekick_Accuracy                0
# Long_Passing                     0
# Ball_Control                     0
# Acceleration                     0
# Sprint_Speed                     0
# Agility                          0
# Reactions                        0
# Balance                          0
# Shot_Power                       0
# Jumping                          0
# Stamina                          0
# Strength                         0
# Long_Shots                       0
# Aggression                       0
# Interceptions                    0
# Positioning                      0
# Vision                           0
# Penalties                        0
# Composure                        0
# Marking                          0
# Standing_Tackle                  0
# Sliding_Tackle                   0
# Gk_Diving                        0
# Gk_Handling                      0
# Gk_Kicking                       0
# Gk_Positioning                   0
# Gk_Reflexes                      0
# dtype: int64

# %%
NoNullmid=dfMF.dropna()

# %%
x=NoNullmid.drop(columns="Value_Euro").values

# %%
# y variable/ target variable 
y= NoNullmid.Value_Euro

# %%
x.shape
# Out:
# (7082, 42)

# %%
y.shape
# Out:
# (7082,)

# %%
y = y.values.reshape(-1,1)

# %%
# split into training and testing sets 
from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1/3, random_state=0)

x_train.shape
# remember had to remove stratisfy because of small data size
# Out:
# (4721, 42)

# %%
model =LinearRegression()

# %%
#fit the model- this needed to be a variable 
c = model.fit(x_train, y_train)

# %%
# Use model to predict on Test Data 
y_pred=c.predict(x_test)
print(y_pred)
# Out:
# [[  919057.45029684]
#  [ 1433834.0437979 ]
#  [12596402.64343295]
#  ...
#  [-2773135.16962939]
#  [ 5102041.41368818]
#  [  708380.55308635]]

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test, y_pred))
# Out:
# 0.6188001956094399

# %%
# plot the results- actual vs predicted 
plt.scatter(y_test, y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %% [markdown]
# # Forwards Model

# %%
# drop addition columns and strings (names, club and national teams, nationality, work rate)
dfFW.drop(['Ls','St','Rs','Lw','Lf','Cf','Rf','Rw','Lam','Cam','Ram','Lm','Lcm','Cm','Rcm','Rm','Lwb','Ldm','Cdm','Rdm','Rwb','Lb','Lcb','Cb','Rcb','Rb','National_Team','Club_Team','Name','Nationality','Work_Rate','Original_Position','Positions'], axis=1, inplace=True)
dfFW.head()
# Out:
# C:\Users\Sydney Kieswetter\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#         Id  Age  Height_Cm  Weight_Kgs  Overall_Rating  Potential  \
# 0   158023   31     170.18        72.1              94         94
# 7   153079   30     172.72        69.9              89         89
# 9   179813   32     185.42        77.1              89         89
# 13  194765   27     175.26        73.0              89         90
# 18  167664   31     185.42        88.9              87         87
#
#      Value_Euro  International_Reputation_1_5  Skill_Moves_1_5  Crossing  ...  \
# 0   110500000.0                             5                4        86  ...
# 7    64500000.0                             4                4        70  ...
# 9    60000000.0                             4                3        70  ...
# 13   78000000.0                             4                4        82  ...
# 18   48500000.0                             4                3        68  ...
#
#     Penalties  Composure  Marking  Standing_Tackle  Sliding_Tackle  Gk_Diving  \
# 0          75         96       33               28              26          6
# 7          83         90       30               20              12         13
# 9          85         82       52               45              39         12
# 13         83         89       59               54              48         14
# 18         70         86       35               22              18          5
#
#     Gk_Handling  Gk_Kicking  Gk_Positioning  Gk_Reflexes
# 0            11          15              14            8
# 7            15           6              11           14
# 9             5          13              13           10
# 13            8          14              13           14
# 18           12           7               5           10
#
# [5 rows x 43 columns]

# %%
dfFW.isnull().sum()
# Out:
# Id                               0
# Age                              0
# Height_Cm                        0
# Weight_Kgs                       0
# Overall_Rating                   0
# Potential                        0
# Value_Euro                      34
# International_Reputation_1_5     0
# Skill_Moves_1_5                  0
# Crossing                         0
# Finishing                        0
# Heading_Accuracy                 0
# Short_Passing                    0
# Volleys                          0
# Dribbling                        0
# Curve                            0
# Freekick_Accuracy                0
# Long_Passing                     0
# Ball_Control                     0
# Acceleration                     0
# Sprint_Speed                     0
# Agility                          0
# Reactions                        0
# Balance                          0
# Shot_Power                       0
# Jumping                          0
# Stamina                          0
# Strength                         0
# Long_Shots                       0
# Aggression                       0
# Interceptions                    0
# Positioning                      0
# Vision                           0
# Penalties                        0
# Composure                        0
# Marking                          0
# Standing_Tackle                  0
# Sliding_Tackle                   0
# Gk_Diving                        0
# Gk_Handling                      0
# Gk_Kicking                       0
# Gk_Positioning                   0
# Gk_Reflexes                      0
# dtype: int64

# %%
NoNullforward=dfFW.dropna()

# %%
x=NoNullforward.drop(columns="Value_Euro").values

# %%
# y variable/ target variable 
y= NoNullforward.Value_Euro

# %%
x.shape
# Out:
# (2570, 42)

# %%
y.shape
# Out:
# (2570,)

# %%
y = y.values.reshape(-1,1)

# %%
# split into training and testing sets 
from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1/3, random_state=0)

x_train.shape
# remember had to remove stratisfy because of small data size
# Out:
# (1713, 42)

# %%
model =LinearRegression()

# %%
#fit the model- this needed to be a variable 
c = model.fit(x_train, y_train)

# %%
# Use model to predict on Test Data 
y_pred=c.predict(x_test)
print(y_pred)
# Out:
# [[ 2.85007944e+05]
#  [ 1.20589999e+07]
#  [ 4.97358509e+06]
#  [ 7.57839190e+06]
#  [ 4.33743121e+05]
#  [ 4.79879357e+06]
#  [ 3.69340902e+06]
#  [ 3.21264408e+06]
#  [ 2.35949600e+06]
#  [ 4.31976845e+06]
#  [-1.39133997e+04]
#  [-5.31204866e+05]
#  [ 2.07673896e+06]
#  [ 3.31604311e+06]
#  [-1.57709538e+06]
#  [-1.75374332e+06]
#  [ 2.35995620e+06]
#  [-3.06229452e+06]
#  [ 9.19136476e+05]
#  [ 8.53643945e+05]
#  [ 8.27679196e+06]
#  [-3.47202359e+06]
#  [ 1.04119152e+06]
#  [ 4.07719785e+06]
#  [-5.05038313e+05]
#  [-7.00344975e+05]
#  [ 1.48819551e+06]
#  [ 1.15065227e+07]
#  [ 1.46592034e+07]
#  [-1.37772275e+06]
#  [-2.79874361e+05]
#  [-1.85067242e+05]
#  [-1.75780533e+06]
#  [ 2.47624468e+07]
#  [ 3.39322559e+06]
#  [ 9.55729509e+05]
#  [ 2.38520973e+06]
#  [-1.75236813e+05]
#  [-7.06732308e+05]
#  [ 4.89065285e+06]
#  [-2.55397905e+06]
#  [ 1.56062741e+06]
#  [ 1.72046688e+06]
#  [ 3.74878510e+06]
#  [-3.10985331e+05]
#  [ 1.31139963e+06]
#  [-3.02506969e+06]
#  [ 2.45384135e+06]
#  [-2.16880493e+06]
#  [ 2.90662004e+07]
#  [ 4.10235182e+05]
#  [-3.13289424e+06]
#  [ 3.09519359e+06]
#  [-3.93471137e+06]
#  [ 4.36651381e+06]
#  [ 4.26668290e+06]
#  [ 4.46712570e+06]
#  [ 1.20890752e+07]
#  [ 9.35820909e+05]
#  [-1.58536358e+06]
#  [ 1.14193220e+07]
#  [ 2.36381929e+07]
#  [ 2.46941524e+05]
#  [ 9.70823823e+05]
#  [ 3.71999827e+06]
#  [ 1.84350973e+06]
#  [ 1.70160009e+04]
#  [-9.61822810e+04]
#  [-9.64042268e+05]
#  [-3.78095267e+06]
#  [ 7.54553593e+06]
#  [ 2.24885361e+06]
#  [ 4.00124213e+06]
#  [-1.99564931e+06]
#  [ 4.11755986e+06]
#  [ 4.01974951e+06]
#  [ 6.74241465e+06]
#  [ 2.16970489e+06]
#  [-3.22232748e+06]
#  [ 2.43732736e+06]
#  [ 2.99185744e+06]
#  [-2.67724974e+06]
#  [-4.28711509e+06]
#  [-8.35764641e+05]
#  [ 4.34764788e+06]
#  [ 1.41237246e+07]
#  [-7.38188907e+05]
#  [ 4.46149883e+06]
#  [ 4.22973703e+06]
#  [-4.28342468e+05]
#  [ 1.08278417e+07]
#  [ 1.88569111e+07]
#  [ 1.49477687e+07]
#  [-1.38992544e+06]
#  [ 3.04603820e+06]
#  [-9.97453851e+05]
#  [ 2.81726994e+06]
#  [-2.53016260e+06]
#  [-3.13790638e+06]
#  [ 4.34373421e+06]
#  [ 5.25215704e+05]
#  [ 9.83921086e+06]
#  [ 5.64016654e+06]
#  [ 3.39003287e+06]
#  [-2.13095799e+05]
#  [ 4.86504960e+05]
#  [ 2.93766538e+05]
#  [-2.67508088e+06]
#  [-1.66811638e+05]
#  [ 3.72576563e+06]
#  [ 1.81948569e+06]
#  [ 1.48159680e+07]
#  [-2.96815829e+06]
#  [ 3.74489501e+06]
#  [ 7.17153182e+05]
#  [-4.89246535e+05]
#  [ 1.76936426e+06]
#  [-4.01521506e+06]
#  [-2.07188468e+06]
#  [-4.35490306e+06]
#  [ 1.19873056e+06]
#  [-4.92783649e+05]
#  [ 3.99366325e+06]
#  [ 2.60619530e+06]
#  [ 2.73407327e+06]
#  [ 4.86591339e+06]
#  [-1.17270069e+05]
#  [-5.37804907e+06]
#  [-3.37191785e+05]
#  [ 5.56516233e+06]
#  [ 5.25335883e+06]
#  [-3.70491082e+06]
#  [-2.98928816e+06]
#  [ 4.80891281e+06]
#  [-9.17514978e+05]
#  [ 4.23719633e+06]
#  [ 2.01734711e+06]
#  [ 3.37947348e+06]
#  [ 4.07008543e+06]
#  [ 5.04226284e+06]
#  [ 4.33531454e+05]
#  [-7.64679803e+05]
#  [-4.72776665e+04]
#  [-4.19184133e+05]
#  [ 5.63121910e+06]
#  [-2.82075646e+06]
#  [ 3.56851993e+06]
#  [ 4.67836507e+06]
#  [ 6.02156941e+05]
#  [-5.69199778e+05]
#  [ 3.35156042e+06]
#  [ 2.71391225e+06]
#  [-7.35020889e+05]
#  [ 4.09969343e+06]
#  [-3.04029158e+06]
#  [ 7.17655075e+06]
#  [ 3.31547372e+06]
#  [-5.00261313e+05]
#  [ 3.85001047e+06]
#  [ 1.15126499e+07]
#  [ 1.17915310e+06]
#  [ 4.73145490e+06]
#  [-6.44568186e+04]
#  [ 5.83379281e+06]
#  [ 3.71354886e+06]
#  [ 2.29095752e+06]
#  [-1.97240612e+06]
#  [-3.18993019e+06]
#  [-3.94765088e+06]
#  [-5.79860738e+06]
#  [ 1.05214262e+07]
#  [ 3.91612998e+06]
#  [ 1.72147745e+06]
#  [-3.88111378e+04]
#  [ 5.10584579e+06]
#  [-1.33924924e+06]
#  [ 3.85922359e+06]
#  [ 3.71686286e+06]
#  [-1.07690195e+06]
#  [ 1.45353045e+06]
#  [ 3.96881240e+06]
#  [ 1.21040684e+07]
#  [ 3.80262093e+06]
#  [ 5.72709113e+06]
#  [ 1.68077639e+06]
#  [-1.00527201e+06]
#  [-2.51473052e+06]
#  [ 3.17987700e+06]
#  [-6.20731708e+05]
#  [ 1.02521623e+07]
#  [ 8.31567131e+06]
#  [ 8.99372191e+05]
#  [ 5.15827254e+05]
#  [-1.20505796e+06]
#  [ 2.60183644e+07]
#  [-1.77524081e+06]
#  [ 2.46078648e+06]
#  [ 2.62646990e+06]
#  [ 7.87825389e+06]
#  [-8.42720895e+05]
#  [ 5.77795980e+05]
#  [ 7.19774586e+06]
#  [ 1.47000901e+07]
#  [-6.73541077e+05]
#  [-7.92485975e+05]
#  [-3.14204682e+05]
#  [ 1.06695937e+06]
#  [ 4.86612209e+06]
#  [ 2.14050538e+05]
#  [-2.24279922e+06]
#  [ 2.08287359e+06]
#  [ 1.64642441e+07]
#  [-2.22039379e+06]
#  [ 4.40154189e+05]
#  [ 2.15893199e+06]
#  [ 1.92428557e+05]
#  [ 4.14936196e+06]
#  [-3.00824748e+06]
#  [ 1.76478562e+06]
#  [ 2.28847110e+06]
#  [ 1.82850531e+06]
#  [-3.03341020e+06]
#  [-3.82642623e+05]
#  [ 9.56488910e+05]
#  [ 1.91887842e+06]
#  [-2.15908194e+06]
#  [ 2.80918236e+06]
#  [ 7.54972666e+06]
#  [ 9.54835448e+05]
#  [ 3.13569499e+06]
#  [ 1.14913757e+07]
#  [ 3.23030465e+06]
#  [ 1.87772986e+06]
#  [-1.05934542e+06]
#  [ 1.38087919e+06]
#  [ 3.42285501e+07]
#  [-1.75688469e+06]
#  [ 1.69038080e+06]
#  [ 4.45864661e+06]
#  [ 8.37424094e+05]
#  [ 4.20195706e+06]
#  [ 7.77062610e+06]
#  [-1.21653009e+06]
#  [-3.34370588e+06]
#  [ 3.14928811e+06]
#  [ 3.09188348e+06]
#  [ 2.22339710e+06]
#  [ 3.95291753e+06]
#  [ 4.90197790e+06]
#  [ 3.19266419e+05]
#  [ 1.01604384e+06]
#  [ 3.62551021e+06]
#  [-2.83707313e+05]
#  [-1.50052602e+06]
#  [-3.72482298e+06]
#  [ 1.74265322e+06]
#  [-1.17833922e+06]
#  [ 5.55422261e+06]
#  [-2.29746938e+06]
#  [ 4.73137100e+05]
#  [ 2.24075715e+05]
#  [-6.75554867e+05]
#  [ 2.48133481e+06]
#  [-3.54624630e+05]
#  [-2.12997067e+06]
#  [-1.23461896e+06]
#  [-3.68700709e+06]
#  [ 2.62630126e+06]
#  [ 2.70152980e+06]
#  [ 5.93466896e+06]
#  [-1.83899747e+06]
#  [ 2.67211722e+06]
#  [ 4.82573212e+06]
#  [ 3.40837186e+06]
#  [ 4.74024956e+06]
#  [ 4.48507394e+06]
#  [-1.75119681e+06]
#  [-1.19300600e+06]
#  [-1.53233704e+06]
#  [ 2.42328800e+05]
#  [ 1.15351024e+07]
#  [ 7.52805109e+06]
#  [ 1.53270909e+06]
#  [ 1.51540611e+07]
#  [-1.66547550e+06]
#  [ 2.69389185e+06]
#  [ 1.39266920e+06]
#  [ 8.42858956e+06]
#  [ 5.07734039e+06]
#  [ 2.42170376e+05]
#  [ 1.15019415e+06]
#  [ 1.09297758e+06]
#  [ 1.62843833e+06]
#  [-1.01067040e+06]
#  [-8.57537937e+05]
#  [ 6.58414946e+06]
#  [ 4.48048482e+04]
#  [ 3.07917740e+06]
#  [ 1.21395320e+07]
#  [ 7.90612740e+06]
#  [ 1.97321648e+06]
#  [-2.58123030e+05]
#  [-8.72187426e+05]
#  [ 5.02892515e+06]
#  [ 4.36354271e+06]
#  [ 6.25228318e+05]
#  [ 1.24396922e+06]
#  [ 5.27496376e+06]
#  [ 4.40274846e+06]
#  [ 1.26528547e+06]
#  [-3.39070956e+06]
#  [-1.74046983e+06]
#  [ 5.71434505e+05]
#  [ 7.32491852e+06]
#  [ 6.50998308e+06]
#  [ 9.42075445e+05]
#  [ 8.39664715e+06]
#  [ 2.62565179e+06]
#  [ 2.95459273e+07]
#  [-5.02975402e+05]
#  [ 2.25177595e+06]
#  [ 1.70991391e+07]
#  [-2.15737376e+06]
#  [-2.37522060e+06]
#  [ 1.15761638e+07]
#  [-2.67008418e+06]
#  [ 3.08217150e+06]
#  [ 3.30921661e+06]
#  [ 1.06345893e+06]
#  [ 5.96468750e+06]
#  [-1.17395650e+06]
#  [ 2.14622000e+06]
#  [ 1.44492295e+07]
#  [ 2.41514845e+06]
#  [ 4.28198297e+05]
#  [ 6.72569951e+05]
#  [-2.41668280e+06]
#  [ 4.34087320e+05]
#  [ 1.20087193e+07]
#  [ 7.55402152e+06]
#  [ 1.40445048e+06]
#  [ 1.33849533e+06]
#  [ 1.71983391e+06]
#  [ 1.21901616e+06]
#  [ 1.56439218e+06]
#  [ 1.82583155e+06]
#  [ 3.24127142e+07]
#  [-1.10739675e+06]
#  [ 3.48368298e+06]
#  [-1.91278716e+06]
#  [-6.06235346e+05]
#  [ 5.49811261e+06]
#  [ 2.56165568e+06]
#  [ 1.14838981e+07]
#  [-3.75364341e+05]
#  [ 3.91010672e+06]
#  [ 2.52746882e+06]
#  [ 5.83718612e+06]
#  [ 2.46716938e+06]
#  [ 1.14883395e+07]
#  [ 2.56926846e+05]
#  [ 7.36715669e+06]
#  [ 4.75298904e+05]
#  [-4.28619722e+05]
#  [ 3.34390420e+06]
#  [ 1.39904494e+06]
#  [ 1.77302249e+06]
#  [ 4.38042233e+06]
#  [-6.34362680e+05]
#  [-4.09991896e+05]
#  [ 1.94762688e+06]
#  [ 1.91589733e+06]
#  [ 4.61872901e+06]
#  [ 2.98899595e+06]
#  [-2.77040474e+06]
#  [-2.15981104e+06]
#  [ 3.22486615e+06]
#  [ 2.02581673e+06]
#  [ 2.38555721e+07]
#  [ 6.94001326e+05]
#  [ 4.09109729e+06]
#  [ 3.90524225e+06]
#  [ 4.29871149e+06]
#  [ 5.95957445e+06]
#  [ 1.86714752e+05]
#  [ 1.79558549e+06]
#  [-2.21373518e+03]
#  [ 1.44202284e+06]
#  [-8.92767489e+05]
#  [-7.11365642e+05]
#  [-7.91831865e+05]
#  [ 2.62307634e+06]
#  [ 1.19224244e+07]
#  [ 3.81844558e+06]
#  [ 1.69860833e+07]
#  [ 5.24343027e+05]
#  [-2.18321956e+05]
#  [-2.66003866e+05]
#  [ 8.84831446e+06]
#  [ 3.21027206e+07]
#  [ 3.97466848e+05]
#  [ 7.17585138e+05]
#  [ 2.79549181e+06]
#  [ 1.41321684e+07]
#  [ 3.39680572e+05]
#  [ 1.79626625e+06]
#  [ 4.06488482e+06]
#  [ 3.89940555e+06]
#  [-2.67564847e+05]
#  [ 4.58349007e+06]
#  [-2.34179955e+05]
#  [-1.43780192e+06]
#  [ 1.72719725e+06]
#  [-4.42434088e+06]
#  [ 2.25480811e+06]
#  [ 1.80188540e+06]
#  [ 7.24664940e+06]
#  [ 5.52731737e+06]
#  [ 1.07045708e+06]
#  [ 1.34523844e+04]
#  [ 6.05846023e+05]
#  [ 2.55816216e+06]
#  [ 1.66526575e+06]
#  [-7.09732425e+05]
#  [-1.80353695e+06]
#  [ 8.16445674e+06]
#  [ 7.97096664e+06]
#  [ 1.45125246e+07]
#  [ 1.17377862e+06]
#  [ 5.87871667e+05]
#  [ 1.67794270e+06]
#  [ 2.49686636e+06]
#  [ 1.51834265e+06]
#  [ 3.78444340e+06]
#  [ 5.66812769e+06]
#  [ 2.75757204e+06]
#  [ 1.21976658e+07]
#  [ 1.05097593e+07]
#  [ 2.03301344e+06]
#  [ 6.00176658e+05]
#  [ 1.27626858e+06]
#  [ 5.27555070e+06]
#  [ 1.14419809e+06]
#  [ 4.18332502e+06]
#  [-3.78014110e+06]
#  [ 1.31497260e+06]
#  [ 6.83756005e+06]
#  [ 1.29548716e+06]
#  [ 2.16962289e+06]
#  [ 8.43627206e+06]
#  [ 3.67147324e+06]
#  [ 5.23468572e+06]
#  [ 2.10605107e+06]
#  [ 1.49831892e+06]
#  [-1.34339328e+06]
#  [-3.96441933e+05]
#  [ 2.84166420e+06]
#  [-4.87729762e+05]
#  [ 8.78247990e+06]
#  [ 5.47345625e+06]
#  [-2.61263806e+06]
#  [ 9.89697872e+05]
#  [-1.04262619e+06]
#  [ 3.08055167e+05]
#  [ 2.34525594e+06]
#  [ 2.75340248e+06]
#  [-1.07755560e+06]
#  [-2.64981128e+06]
#  [ 9.12423402e+06]
#  [ 6.70464011e+06]
#  [ 3.14686043e+05]
#  [ 4.69980867e+06]
#  [ 4.32493613e+05]
#  [ 2.74100297e+06]
#  [-1.56205557e+06]
#  [ 1.19802471e+06]
#  [ 1.24445302e+06]
#  [ 2.72094284e+06]
#  [-5.91247458e+05]
#  [ 1.18696976e+06]
#  [-3.97799466e+06]
#  [ 6.91789760e+06]
#  [ 6.15412486e+06]
#  [ 5.57253159e+06]
#  [ 1.27720494e+07]
#  [ 1.06408551e+06]
#  [ 3.03579346e+06]
#  [ 1.79797825e+06]
#  [ 1.62897373e+07]
#  [-8.53943820e+05]
#  [-1.57369900e+06]
#  [ 1.55859065e+06]
#  [ 1.01066691e+06]
#  [ 4.07010989e+06]
#  [ 4.61602428e+06]
#  [ 1.69803733e+07]
#  [ 1.47741505e+07]
#  [ 6.52727445e+05]
#  [ 3.46613588e+06]
#  [ 4.70964156e+06]
#  [ 1.43283185e+06]
#  [ 1.04083160e+06]
#  [ 5.53695116e+06]
#  [-3.39105273e+06]
#  [-1.65515871e+06]
#  [ 3.66833330e+06]
#  [ 4.56110173e+06]
#  [ 2.24773200e+06]
#  [ 1.55589022e+06]
#  [-4.64133595e+05]
#  [ 6.21824481e+06]
#  [-2.11763283e+06]
#  [-9.67674623e+05]
#  [ 5.20550843e+06]
#  [ 7.26644079e+06]
#  [ 2.72418413e+06]
#  [ 3.30733256e+07]
#  [ 1.49269091e+04]
#  [ 4.40304242e+06]
#  [-2.08266691e+05]
#  [-3.08148298e+06]
#  [ 6.46581813e+06]
#  [ 1.79754480e+06]
#  [ 1.23857303e+06]
#  [ 5.08020871e+06]
#  [-5.49506971e+05]
#  [ 3.65342826e+05]
#  [-1.33383137e+06]
#  [ 8.15661289e+05]
#  [ 3.78925006e+06]
#  [ 6.04825299e+06]
#  [ 3.61156382e+06]
#  [ 1.68661357e+06]
#  [ 3.01224878e+05]
#  [-1.58514867e+06]
#  [-1.18136188e+06]
#  [ 2.99177993e+06]
#  [ 3.78799317e+06]
#  [-3.26696696e+06]
#  [ 3.75483665e+06]
#  [ 1.94781489e+05]
#  [ 6.47440862e+06]
#  [ 4.99147223e+06]
#  [-2.00370558e+06]
#  [ 2.15063631e+07]
#  [ 2.86274344e+06]
#  [ 4.74317794e+05]
#  [-2.00605813e+06]
#  [ 1.32774243e+06]
#  [ 1.51200897e+06]
#  [ 1.96955912e+06]
#  [ 8.46446625e+06]
#  [-1.24815294e+06]
#  [ 6.62015064e+06]
#  [ 6.43856402e+05]
#  [-3.98983307e+04]
#  [-1.16492379e+06]
#  [-8.89987541e+06]
#  [-2.11597111e+06]
#  [-5.16691355e+06]
#  [ 9.32061599e+06]
#  [ 3.77233148e+06]
#  [ 1.07974051e+06]
#  [ 2.08866497e+06]
#  [ 1.43890953e+07]
#  [-1.68684828e+06]
#  [ 5.40801983e+05]
#  [ 2.64888209e+06]
#  [ 7.93723120e+06]
#  [ 3.31179529e+06]
#  [ 1.76996184e+05]
#  [ 1.32309222e+05]
#  [ 5.52316653e+06]
#  [ 2.52629374e+07]
#  [ 6.32172225e+06]
#  [ 8.12002502e+06]
#  [ 2.71974605e+06]
#  [ 1.33901115e+07]
#  [-2.54980346e+06]
#  [ 2.48035329e+06]
#  [-2.94326379e+06]
#  [ 1.14950150e+07]
#  [ 7.59263797e+06]
#  [-1.91098837e+06]
#  [-2.44637693e+06]
#  [ 8.29165428e+05]
#  [ 2.53614214e+06]
#  [ 2.16657153e+06]
#  [-1.64007139e+06]
#  [ 8.72501245e+05]
#  [-8.77380971e+05]
#  [-2.90301103e+06]
#  [-3.55876327e+05]
#  [ 3.26319939e+06]
#  [ 3.18361685e+06]
#  [ 1.74441911e+06]
#  [-8.27384027e+05]
#  [ 2.73373764e+06]
#  [-4.60360283e+06]
#  [ 5.85342462e+06]
#  [ 2.10798982e+07]
#  [ 3.56071308e+06]
#  [ 8.14932045e+05]
#  [ 1.61053243e+06]
#  [ 1.63650425e+06]
#  [ 1.41596575e+06]
#  [ 1.68236173e+06]
#  [ 3.05556946e+06]
#  [ 6.81808782e+06]
#  [-1.81219384e+05]
#  [ 2.31156848e+06]
#  [ 2.75209542e+06]
#  [ 1.89325548e+07]
#  [-3.74691089e+06]
#  [ 1.18974325e+07]
#  [ 1.13673579e+07]
#  [-2.57274682e+06]
#  [ 7.01532167e+06]
#  [ 1.81886631e+06]
#  [-6.62050862e+06]
#  [ 4.46968966e+06]
#  [ 8.48666778e+06]
#  [-3.81220729e+05]
#  [ 3.52229846e+06]
#  [ 9.15969893e+06]
#  [ 1.07689511e+07]
#  [ 2.17554840e+06]
#  [ 4.28470977e+06]
#  [ 4.89835299e+07]
#  [ 1.38750097e+06]
#  [ 9.54090206e+05]
#  [-5.13997672e+06]
#  [ 1.27200115e+06]
#  [ 1.48887688e+06]
#  [-1.32277685e+06]
#  [ 4.52406615e+06]
#  [ 7.02460431e+06]
#  [ 5.27126850e+06]
#  [-1.70034461e+06]
#  [ 2.68441839e+06]
#  [ 3.45270158e+06]
#  [ 2.95433750e+06]
#  [ 1.93606880e+06]
#  [ 2.78428311e+06]
#  [ 7.50948445e+06]
#  [ 1.08999740e+07]
#  [ 4.62865236e+06]
#  [ 2.52810932e+06]
#  [ 3.29757801e+06]
#  [ 9.59487611e+06]
#  [-1.41942772e+06]
#  [ 3.20681547e+07]
#  [ 2.58117665e+06]
#  [ 2.94301342e+06]
#  [-2.47355531e+06]
#  [ 1.82543723e+06]
#  [ 2.85574657e+06]
#  [ 2.26730915e+06]
#  [-1.64726942e+06]
#  [ 2.82997109e+05]
#  [ 2.87017850e+06]
#  [-3.51522049e+06]
#  [ 3.97514806e+06]
#  [ 4.28432111e+06]
#  [ 3.79571184e+06]
#  [-7.52000039e+05]
#  [ 2.27375394e+06]
#  [-7.29082040e+06]
#  [ 2.40298400e+06]
#  [ 1.95164797e+07]
#  [ 4.30867578e+06]
#  [ 1.30248096e+05]
#  [ 3.09787552e+06]
#  [ 2.06057317e+06]
#  [ 1.39118423e+07]
#  [-1.26339554e+06]
#  [ 2.31034412e+06]
#  [-7.04386326e+05]
#  [-3.89335686e+05]
#  [ 2.99614036e+06]
#  [ 1.58442764e+06]
#  [-1.82382832e+06]
#  [-1.31266435e+05]
#  [-2.82490120e+06]
#  [-6.42553161e+05]
#  [ 2.73149384e+07]
#  [ 3.71879724e+05]
#  [-2.92375291e+06]
#  [-1.14508701e+06]
#  [ 1.93808552e+07]
#  [ 2.64304738e+06]
#  [ 7.07491231e+06]
#  [ 1.63965028e+06]
#  [ 3.15841269e+06]
#  [ 1.91232914e+07]
#  [ 1.35673191e+07]
#  [ 2.32233775e+05]
#  [ 6.93132241e+06]
#  [ 3.28132813e+06]
#  [ 2.18439406e+06]
#  [ 7.24372233e+05]
#  [ 1.03211514e+06]
#  [ 5.41169192e+06]
#  [-3.38549352e+06]
#  [ 8.62945229e+05]
#  [ 3.31155272e+06]
#  [ 3.47177156e+06]
#  [ 1.04806700e+07]
#  [ 3.64029983e+05]
#  [ 7.65819408e+06]
#  [-2.25006919e+06]
#  [ 1.70708281e+06]
#  [-1.18322023e+06]
#  [ 4.66052580e+06]
#  [ 1.70976826e+06]
#  [ 2.42856283e+06]
#  [-3.09752717e+05]
#  [-6.16979626e+06]
#  [ 1.91970492e+07]
#  [ 1.56120249e+06]
#  [ 1.08617751e+07]
#  [-2.91164616e+06]
#  [-5.18539777e+05]
#  [ 6.21494694e+06]
#  [ 8.03646777e+05]
#  [ 3.77345359e+06]
#  [ 4.57308346e+05]
#  [ 1.44461477e+06]
#  [ 3.65903562e+05]
#  [ 1.69182843e+06]
#  [ 4.05426365e+06]
#  [ 7.61457624e+05]
#  [ 1.07099696e+07]
#  [-4.44948810e+05]
#  [-3.94268016e+06]
#  [ 1.79312731e+06]
#  [ 2.69925203e+06]
#  [ 1.13707813e+07]
#  [-9.34482898e+05]
#  [-1.83346923e+06]
#  [ 1.25247613e+06]
#  [ 6.73913216e+06]
#  [-2.19028361e+06]
#  [ 4.30775487e+06]
#  [ 2.78775926e+06]
#  [ 1.27354750e+06]
#  [ 3.88630521e+06]
#  [ 2.48273473e+06]
#  [-1.54639655e+06]
#  [ 3.00790914e+07]
#  [ 1.54774894e+06]
#  [-1.15512018e+06]
#  [-1.25149672e+05]
#  [-3.10234715e+06]
#  [ 6.22732373e+06]
#  [ 5.86362693e+05]
#  [-1.21154505e+06]
#  [ 2.55289252e+06]
#  [ 2.03681735e+06]
#  [ 5.19993670e+06]
#  [-1.21891262e+05]
#  [ 2.59374196e+06]
#  [ 2.15554165e+06]
#  [ 6.91313312e+05]
#  [-1.37278806e+05]
#  [ 1.28040823e+07]
#  [ 1.83093963e+06]
#  [ 1.06480268e+06]
#  [ 4.20568067e+06]
#  [-5.69600686e+05]
#  [ 3.29431100e+06]
#  [-9.79961156e+04]
#  [ 2.52674228e+06]
#  [ 6.15849144e+06]
#  [ 2.28955266e+06]
#  [-6.94871281e+05]
#  [ 5.69449584e+06]
#  [ 7.00766731e+05]
#  [ 4.05704283e+06]
#  [ 2.66397555e+06]
#  [ 8.96853146e+06]
#  [ 1.56618192e+07]
#  [ 1.16978182e+07]
#  [-6.86745426e+05]
#  [-3.41409118e+06]
#  [ 2.41233246e+05]
#  [ 5.68321050e+06]
#  [ 3.28043287e+06]
#  [-3.52271526e+06]
#  [ 3.10363246e+06]
#  [-1.22100560e+05]
#  [-4.03080144e+06]
#  [-2.46312895e+05]
#  [-3.37662597e+05]
#  [ 1.38096865e+06]
#  [ 2.63020974e+04]
#  [-4.24469635e+05]
#  [-1.34351602e+06]
#  [ 7.20259673e+05]
#  [ 5.53357891e+06]
#  [-1.09609943e+06]
#  [ 2.90513994e+06]
#  [-3.10108304e+05]
#  [-1.80583981e+06]
#  [ 4.13091912e+06]
#  [ 6.51379821e+06]
#  [-6.12655015e+06]
#  [-1.04564861e+06]
#  [ 3.07516666e+06]
#  [ 3.32446144e+06]
#  [ 6.62707535e+06]
#  [-9.31728352e+05]
#  [ 2.71408079e+06]
#  [ 7.56738125e+06]
#  [ 2.56722722e+04]
#  [ 2.17706352e+06]
#  [ 8.64816684e+05]
#  [ 8.66079339e+06]
#  [ 5.46107111e+06]
#  [ 6.68375268e+06]
#  [ 6.29896201e+06]
#  [ 9.39050968e+05]
#  [ 2.89719970e+05]
#  [ 3.85111918e+06]
#  [-1.94625215e+06]
#  [ 1.94578948e+06]
#  [ 4.24782576e+06]
#  [-3.13287338e+06]
#  [-2.68059840e+06]
#  [ 2.90234764e+06]
#  [-9.68319961e+05]
#  [ 6.05796729e+06]
#  [-2.08166572e+06]
#  [ 2.85386308e+04]
#  [-3.54110196e+06]
#  [-1.27605967e+06]
#  [ 3.02194241e+06]
#  [ 3.78098889e+06]
#  [ 1.89179059e+06]
#  [-5.78275580e+05]
#  [-1.81111498e+06]
#  [ 8.08111847e+06]
#  [ 3.23472901e+05]
#  [-2.23069060e+06]
#  [ 2.26331355e+06]
#  [ 5.41530335e+06]
#  [ 1.27325163e+06]
#  [ 1.91387869e+06]
#  [ 5.98274312e+06]
#  [ 7.42029207e+06]
#  [ 8.16515757e+06]
#  [ 4.35974312e+06]
#  [ 9.99669585e+05]
#  [ 1.83875386e+07]
#  [-6.25145707e+04]
#  [ 2.78343994e+06]
#  [ 9.69949641e+06]]

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test, y_pred))
# Out:
# 0.7020124614257841

# %%
# plot the results- actual vs predicted 
plt.scatter(y_test, y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')
